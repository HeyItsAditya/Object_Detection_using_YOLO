# %%
import cv2




# Opencv DNN
net = cv2.dnn.readNet("dnn_model/yolov4-tiny.weights", "dnn_model/yolov4-tiny.cfg")
model = cv2.dnn_DetectionModel(net)
model.setInputParams(size=(320, 320), scale=1/255)

# Load class lists
classes = []
with open("dnn_model/classes.txt", "r") as file_object:
    for class_name in file_object.readlines():
        class_name = class_name.strip()
        classes.append(class_name)

print("Objects list")
print(classes)
KNOWN_WIDTH = 20  # Width of the object in real-world units (inches, centimeters, etc.)
FOCAL_LENGTH = 100 


    # Initialize camera
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
# FULL HD 1920 x 1080'''

cv2.namedWindow("Frame")


# Create window

while True:
    # Get frames
    ret, frame = cap.read()

    # Get active buttons list
    #
    #print("Active buttons", active_buttons)

    # Object Detection
    (class_ids, scores, bboxes) = model.detect(frame)
    for class_id, score, bbox in zip(class_ids, scores, bboxes):
        (x,y,w,h) = bbox
        class_name=classes[class_id]
        cv2.putText(frame,(class_name),(x,y-5),cv2.FONT_HERSHEY_PLAIN,2,(255,0,50),2)
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,50),3)
        distance = (KNOWN_WIDTH * FOCAL_LENGTH) / w

        text = f" {distance:.2f} units"  # Modify 'units' to match your real-world units
        cv2.putText(frame, text, (x, y - 20), cv2.FONT_HERSHEY_PLAIN, 0.5, (255, 0, 0), 2)
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        
        print("Class ids", class_id)
        print("Scores", score)
        print("Bboxes", bbox)
        
        

        


    # Display buttons

    cv2.imshow("Frame", frame)
    key = cv2.waitKey(1)
    if key == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Objects list
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
# Class ids 0
# Scores 0.5975047
# Bboxes [  48   35 1075  685]
# Class ids 0
# Scores 0.6778511
# Bboxes [ 181   39 1039  679]
# Class ids 56
# Scores 0.65889037
# Bboxes [876 417 228  50]
# Class ids 56
# Scores 0.5862465
# Bboxes [874 416 229  52]
# Class ids 56
# Scores 0.5862465
# Bboxes [874 416 229  52]
# Class ids 0
# Scores 0.6989189
# Bboxes [ 176   48 1055  672]
# Class ids 0
# Scores 0.50239193
# Bboxes [  43   34 1093  686]
# Class ids 0
# Scores 0.6040252
# Bboxes [  45   40 1092  680]
# Class ids 0
# Scores 0.6885018
# Bboxes [ 187   51 1010  659]
# Class ids 0
# Scores 0.6040252
# Bboxes [  45   40 1092  680]
# Class ids 0
# Scores 0.6885018
# Bboxes [ 187   51 1010  659]
# Class ids 0
# Scores 0.66470766
# Bboxes [ 189   40 1022  679]
# Class ids 0
# Scores 0.66470766
# Bboxes [ 189   40 1022  679]
# Class ids 0
# Scores 0.51161724
# Bboxes [  58   28 1067  692]
# Class ids 0
# Scores 0.6614177
# Bboxes [ 189   37 1016  680]
# Class ids 0
# Scores 0.591638
# Bboxes [220  44 961 675]
# Class ids 0
# Scores 0.591638
# Bboxes [220  44 961 675]
# Class ids 0
# Scores 0.5396416
# Bboxes [220  48 959 664]
# Class ids 0
# Scores 0.52459633
# Bboxes [  69   48 1031  667]
# Class ids 0
# Scores 0.52459633
# Bboxes [  69   48 1031  667]
# Class ids 0
# Scores 0.50758064
# Bboxes [203  48 990 660]
# Class ids 0
# Scores 0.50758064
# Bboxes [203  48 990 660]
# Class ids 0
# Scores 0.50899506
# Bboxes [ 195   23 1004  697]
# Class ids 39
# Scores 0.5962261
# Bboxes [846   0 284 532]
# Class ids 39
# Scores 0.58483195
# Bboxes [836   0 301 663]
# Class ids 39
# Scores 0.6096146
# Bboxes [847   0 295 577]
# Class ids 39
# Scores 0.6564987
# Bboxes [845  24 283 580]
# Class ids 39
# Scores 0.6096146
# Bboxes [847   0 295 577]
# Class ids 39
# Scores 0.6564987
# Bboxes [845  24 283 580]
# Class ids 39
# Scores 0.61994123
# Bboxes [843   0 308 590]
# Class ids 39
# Scores 0.86048245
# Bboxes [839  33 307 568]
# Class ids 39
# Scores 0.8462977
# Bboxes [841  33 305 579]
# Class ids 39
# Scores 0.8462977
# Bboxes [841  33 305 579]
# Class ids 39
# Scores 0.643675
# Bboxes [845   0 295 580]
# Class ids 39
# Scores 0.8575613
# Bboxes [843  38 292 563]
# Class ids 39
# Scores 0.643675
# Bboxes [845   0 295 580]
# Class ids 39
# Scores 0.8575613
# Bboxes [843  38 292 563]
# Class ids 39
# Scores 0.570455
# Bboxes [845   0 286 575]
# Class ids 39
# Scores 0.86238307
# Bboxes [841  34 291 561]
# Class ids 39
# Scores 0.570455
# Bboxes [845   0 286 575]
# Class ids 39
# Scores 0.86238307
# Bboxes [841  34 291 561]
# Class ids 39
# Scores 0.6084183
# Bboxes [845   0 294 577]
# Class ids 39
# Scores 0.9053312
# Bboxes [843  37 293 553]
# Class ids 39
# Scores 0.6084183
# Bboxes [845   0 294 577]
# Class ids 39
# Scores 0.9053312
# Bboxes [843  37 293 553]
# Class ids 39
# Scores 0.5845986
# Bboxes [843   0 296 560]
# Class ids 39
# Scores 0.96428144
# Bboxes [836  38 303 549]
# Class ids 39
# Scores 0.93462247
# Bboxes [837  32 306 568]
# Class ids 39
# Scores 0.6114539
# Bboxes [849   2 277 551]
# Class ids 39
# Scores 0.838039
# Bboxes [840  29 283 567]
# Class ids 39
# Scores 0.6114539
# Bboxes [849   2 277 551]
# Class ids 39
# Scores 0.838039
# Bboxes [840  29 283 567]
# Class ids 39
# Scores 0.61902577
# Bboxes [846   0 286 588]
# Class ids 39
# Scores 0.9531899
# Bboxes [837  38 291 546]
# Class ids 77
# Scores 0.5659835
# Bboxes [1056  397  217  319]
# Class ids 39
# Scores 0.61902577
# Bboxes [846   0 286 588]
# Class ids 39
# Scores 0.9531899
# Bboxes [837  38 291 546]
# Class ids 77
# Scores 0.5659835
# Bboxes [1056  397  217  319]
# Class ids 39
# Scores 0.9268451
# Bboxes [839  36 289 565]
# Class ids 39
# Scores 0.9268451
# Bboxes [839  36 289 565]
# Class ids 39
# Scores 0.5598992
# Bboxes [847   0 287 577]
# Class ids 39
# Scores 0.8672689
# Bboxes [837  44 287 531]
# Class ids 39
# Scores 0.65022796
# Bboxes [849   0 284 583]
# Class ids 39
# Scores 0.9086292
# Bboxes [836  31 291 563]
# Class ids 39
# Scores 0.9571435
# Bboxes [838  35 288 566]
# Class ids 39
# Scores 0.9571435
# Bboxes [838  35 288 566]
# Class ids 39
# Scores 0.58539283
# Bboxes [847   0 282 570]
# Class ids 39
# Scores 0.8841198
# Bboxes [838  41 286 546]
# Class ids 77
# Scores 0.50152
# Bboxes [1049  398  225  322]
# Class ids 39
# Scores 0.58539283
# Bboxes [847   0 282 570]
# Class ids 39
# Scores 0.8841198
# Bboxes [838  41 286 546]
# Class ids 77
# Scores 0.50152
# Bboxes [1049  398  225  322]
# Class ids 39
# Scores 0.57171756
# Bboxes [846   0 279 574]
# Class ids 39
# Scores 0.7954818
# Bboxes [834  37 286 544]
# Class ids 39
# Scores 0.57171756
# Bboxes [846   0 279 574]
# Class ids 39
# Scores 0.7954818
# Bboxes [834  37 286 544]
# Class ids 39
# Scores 0.8522936
# Bboxes [852   0 267 567]
# Class ids 39
# Scores 0.78195065
# Bboxes [833  34 283 544]
# Class ids 0
# Scores 0.5655086
# Bboxes [1014  418  256  291]
# Class ids 39
# Scores 0.8659321
# Bboxes [835  41 282 552]
# Class ids 39
# Scores 0.8659321
# Bboxes [835  41 282 552]
# Class ids 39
# Scores 0.9163095
# Bboxes [835  40 298 552]
# Class ids 77
# Scores 0.58985186
# Bboxes [1052  398  223  320]
# Class ids 39
# Scores 0.9163095
# Bboxes [835  40 298 552]
# Class ids 77
# Scores 0.58985186
# Bboxes [1052  398  223  320]
# Class ids 39
# Scores 0.91873306
# Bboxes [827  34 307 575]
# Class ids 39
# Scores 0.91873306
# Bboxes [827  34 307 575]
# Class ids 39
# Scores 0.8856118
# Bboxes [824  44 306 560]
# Class ids 77
# Scores 0.5130902
# Bboxes [1052  405  225  311]
# Class ids 39
# Scores 0.9563897
# Bboxes [832  44 315 572]
# Class ids 39
# Scores 0.96517336
# Bboxes [834  47 318 558]
# Class ids 39
# Scores 0.96517336
# Bboxes [834  47 318 558]
# Class ids 39
# Scores 0.95800567
# Bboxes [844  45 308 556]
# Class ids 77
# Scores 0.5274956
# Bboxes [1057  415  217  298]
# Class ids 39
# Scores 0.95800567
# Bboxes [844  45 308 556]
# Class ids 77
# Scores 0.5274956
# Bboxes [1057  415  217  298]
# Class ids 39
# Scores 0.9579176
# Bboxes [848  57 315 541]
# Class ids 39
# Scores 0.9579176
# Bboxes [848  57 315 541]
# Class ids 39
# Scores 0.9620007
# Bboxes [852  37 317 588]
# Class ids 39
# Scores 0.9196914
# Bboxes [843  44 327 590]
# Class ids 39
# Scores 0.9287799
# Bboxes [844  32 323 586]
# Class ids 39
# Scores 0.9287799
# Bboxes [844  32 323 586]
# Class ids 39
# Scores 0.84380394
# Bboxes [843  35 331 609]
# Class ids 39
# Scores 0.84380394
# Bboxes [843  35 331 609]
# Class ids 39
# Scores 0.8104853
# Bboxes [838  44 333 588]
# Class ids 39
# Scores 0.8104853
# Bboxes [838  44 333 588]
# Class ids 39
# Scores 0.9444298
# Bboxes [849  37 318 598]
# Class ids 39
# Scores 0.878876
# Bboxes [850  33 318 610]
# Class ids 39
# Scores 0.878876
# Bboxes [850  33 318 610]
# Class ids 39
# Scores 0.9224029
# Bboxes [859  26 303 628]
# Class ids 39
# Scores 0.96361524
# Bboxes [855  21 308 630]
# Class ids 39
# Scores 0.50930667
# Bboxes [829  57 332 634]
# Class ids 39
# Scores 0.96361524
# Bboxes [855  21 308 630]
# Class ids 39
# Scores 0.50930667
# Bboxes [829  57 332 634]
# Class ids 39
# Scores 0.9533914
# Bboxes [855  25 309 612]
# Class ids 39
# Scores 0.9251458
# Bboxes [853  15 313 642]
# Class ids 39
# Scores 0.9251458
# Bboxes [853  15 313 642]
# Class ids 39
# Scores 0.9215654
# Bboxes [855  21 306 645]
# Class ids 39
# Scores 0.9215654
# Bboxes [855  21 306 645]
# Class ids 39
# Scores 0.8444052
# Bboxes [850  16 312 651]
# Class ids 39
# Scores 0.8039998
# Bboxes [855  18 307 648]
# Class ids 39
# Scores 0.91828907
# Bboxes [852  20 310 643]
# Class ids 39
# Scores 0.533827
# Bboxes [833  86 325 582]
# Class ids 39
# Scores 0.91828907
# Bboxes [852  20 310 643]
# Class ids 39
# Scores 0.533827
# Bboxes [833  86 325 582]
# Class ids 39
# Scores 0.9182324
# Bboxes [843  10 324 660]
# Class ids 39
# Scores 0.51072836
# Bboxes [830  96 331 565]
# Class ids 39
# Scores 0.9182324
# Bboxes [843  10 324 660]
# Class ids 39
# Scores 0.51072836
# Bboxes [830  96 331 565]
# Class ids 39
# Scores 0.84372646
# Bboxes [844  17 322 648]
# Class ids 39
# Scores 0.53256214
# Bboxes [832  74 330 604]
# Class ids 39
# Scores 0.84372646
# Bboxes [844  17 322 648]
# Class ids 39
# Scores 0.53256214
# Bboxes [832  74 330 604]
# Class ids 39
# Scores 0.95693415
# Bboxes [867  27 286 625]
# Class ids 39
# Scores 0.6383997
# Bboxes [837  65 319 619]
# Class ids 39
# Scores 0.9459966
# Bboxes [846  15 315 650]
# Class ids 39
# Scores 0.5042109
# Bboxes [833  70 326 610]
# Class ids 39
# Scores 0.857031
# Bboxes [842  18 315 650]
# Class ids 39
# Scores 0.62166965
# Bboxes [838  69 321 609]
# Class ids 39
# Scores 0.857031
# Bboxes [842  18 315 650]
# Class ids 39
# Scores 0.62166965
# Bboxes [838  69 321 609]
# Class ids 39
# Scores 0.9531707
# Bboxes [844  20 310 642]
# Class ids 39
# Scores 0.9531707
# Bboxes [844  20 310 642]
# Class ids 39
# Scores 0.92646146
# Bboxes [839  23 322 628]
# Class ids 39
# Scores 0.92646146
# Bboxes [839  23 322 628]
# Class ids 39
# Scores 0.95348704
# Bboxes [845  17 313 652]
# Class ids 39
# Scores 0.9640018
# Bboxes [840  19 317 647]
# Class ids 39
# Scores 0.5389994
# Bboxes [831  72 328 600]
# Class ids 39
# Scores 0.9640018
# Bboxes [840  19 317 647]
# Class ids 39
# Scores 0.5389994
# Bboxes [831  72 328 600]
# Class ids 39
# Scores 0.9312443
# Bboxes [843  19 314 646]
# Class ids 39
# Scores 0.65983856
# Bboxes [838  58 317 631]
# Class ids 39
# Scores 0.9396256
# Bboxes [839  20 319 643]
# Class ids 39
# Scores 0.6907096
# Bboxes [836  71 320 604]
# Class ids 39
# Scores 0.9396256
# Bboxes [839  20 319 643]
# Class ids 39
# Scores 0.6907096
# Bboxes [836  71 320 604]
# Class ids 39
# Scores 0.9255619
# Bboxes [843  23 312 630]
# Class ids 39
# Scores 0.63236386
# Bboxes [837  70 315 608]
# Class ids 39
# Scores 0.9255619
# Bboxes [843  23 312 630]
# Class ids 39
# Scores 0.63236386
# Bboxes [837  70 315 608]
# Class ids 39
# Scores 0.91711396
# Bboxes [864  37 291 602]
# Class ids 39
# Scores 0.8545488
# Bboxes [840  66 314 622]
# Class ids 39
# Scores 0.7329002
# Bboxes [851  36 307 598]
# Class ids 39
# Scores 0.66916937
# Bboxes [835  80 318 597]
# Class ids 39
# Scores 0.7329002
# Bboxes [851  36 307 598]
# Class ids 39
# Scores 0.66916937
# Bboxes [835  80 318 597]
# Class ids 39
# Scores 0.8235902
# Bboxes [865  35 292 608]
# Class ids 39
# Scores 0.6340751
# Bboxes [830  95 337 573]
# Class ids 39
# Scores 0.81962186
# Bboxes [863  28 294 622]
# Class ids 39
# Scores 0.5691095
# Bboxes [828  93 344 577]
# Class ids 39
# Scores 0.81962186
# Bboxes [863  28 294 622]
# Class ids 39
# Scores 0.5691095
# Bboxes [828  93 344 577]
# Class ids 39
# Scores 0.6590484
# Bboxes [869  22 288 625]
# Class ids 39
# Scores 0.9066679
# Bboxes [841  89 328 599]
# Class ids 39
# Scores 0.8385145
# Bboxes [840  96 333 595]
# Class ids 39
# Scores 0.8385145
# Bboxes [840  96 333 595]
# Class ids 39
# Scores 0.6463302
# Bboxes [834  84 343 605]
# Class ids 39
# Scores 0.6463302
# Bboxes [834  84 343 605]
# Class ids 39
# Scores 0.9080834
# Bboxes [831  88 353 601]
# Class ids 39
# Scores 0.9491314
# Bboxes [831 117 326 584]
# Class ids 39
# Scores 0.96392107
# Bboxes [824 123 321 577]
# Class ids 39
# Scores 0.96392107
# Bboxes [824 123 321 577]
# Class ids 39
# Scores 0.97659683
# Bboxes [831 113 310 596]
# Class ids 39
# Scores 0.97659683
# Bboxes [831 113 310 596]
# Class ids 39
# Scores 0.97964483
# Bboxes [831 121 300 579]
# Class ids 39
# Scores 0.65777826
# Bboxes [831 178 304 520]
# Class ids 39
# Scores 0.97964483
# Bboxes [831 121 300 579]
# Class ids 39
# Scores 0.65777826
# Bboxes [831 178 304 520]
# Class ids 39
# Scores 0.9844971
# Bboxes [835 113 284 584]
# Class ids 39
# Scores 0.5447436
# Bboxes [827 184 299 515]
# Class ids 39
# Scores 0.9563536
# Bboxes [831 110 290 592]
# Class ids 39
# Scores 0.9563536
# Bboxes [831 110 290 592]
# Class ids 39
# Scores 0.81419015
# Bboxes [821 107 301 584]
# Class ids 39
# Scores 0.81419015
# Bboxes [821 107 301 584]
# Class ids 39
# Scores 0.94185066
# Bboxes [824 111 290 589]
# Class ids 0
# Scores 0.5576893
# Bboxes [1003  547  267  167]
# Class ids 39
# Scores 0.94185066
# Bboxes [824 111 290 589]
# Class ids 0
# Scores 0.5576893
# Bboxes [1003  547  267  167]
# Class ids 39
# Scores 0.8827197
# Bboxes [831 100 291 620]
# Class ids 39
# Scores 0.8267074
# Bboxes [835 195 290 525]
# Class ids 39
# Scores 0.89653385
# Bboxes [826 113 296 607]
# Class ids 39
# Scores 0.92196107
# Bboxes [825 219 301 500]
# Class ids 39
# Scores 0.9145588
# Bboxes [829 103 299 617]
# Class ids 39
# Scores 0.9020477
# Bboxes [826 209 312 498]
# Class ids 39
# Scores 0.9145588
# Bboxes [829 103 299 617]
# Class ids 39
# Scores 0.9020477
# Bboxes [826 209 312 498]
# Class ids 39
# Scores 0.85955536
# Bboxes [833 101 298 619]
# Class ids 39
# Scores 0.9660244
# Bboxes [824 219 317 501]
# Class ids 39
# Scores 0.85955536
# Bboxes [833 101 298 619]
# Class ids 39
# Scores 0.9660244
# Bboxes [824 219 317 501]
# Class ids 39
# Scores 0.80235565
# Bboxes [830  96 298 624]
# Class ids 39
# Scores 0.94383305
# Bboxes [831 231 306 489]
# Class ids 39
# Scores 0.80235565
# Bboxes [830  96 298 624]
# Class ids 39
# Scores 0.94383305
# Bboxes [831 231 306 489]
# Class ids 39
# Scores 0.8282314
# Bboxes [836  94 295 626]
# Class ids 39
# Scores 0.9251333
# Bboxes [832 221 311 499]
# Class ids 39
# Scores 0.8813538
# Bboxes [834 103 302 615]
# Class ids 39
# Scores 0.94466704
# Bboxes [831 218 316 502]
# Class ids 39
# Scores 0.5911026
# Bboxes [838  98 299 622]
# Class ids 39
# Scores 0.92279094
# Bboxes [829 230 320 490]
# Class ids 39
# Scores 0.5911026
# Bboxes [838  98 299 622]
# Class ids 39
# Scores 0.92279094
# Bboxes [829 230 320 490]
# Class ids 39
# Scores 0.9146424
# Bboxes [829 231 321 489]
# Class ids 39
# Scores 0.9146424
# Bboxes [829 231 321 489]
# Class ids 39
# Scores 0.7432234
# Bboxes [855 113 278 607]
# Class ids 39
# Scores 0.8977116
# Bboxes [833 222 323 496]
# Class ids 39
# Scores 0.7432234
# Bboxes [855 113 278 607]
# Class ids 39
# Scores 0.8977116
# Bboxes [833 222 323 496]
# Class ids 39
# Scores 0.9475596
# Bboxes [841 228 314 492]
# Class ids 39
# Scores 0.92436266
# Bboxes [836 241 322 479]
# Class ids 39
# Scores 0.92436266
# Bboxes [836 241 322 479]
# Class ids 39
# Scores 0.9505767
# Bboxes [843 227 325 493]
# Class ids 39
# Scores 0.9221608
# Bboxes [834 206 345 499]
# Class ids 39
# Scores 0.9221608
# Bboxes [834 206 345 499]
# Class ids 39
# Scores 0.95135784
# Bboxes [840 200 328 520]
# Class ids 39
# Scores 0.5156446
# Bboxes [852 106 300 614]
# Class ids 39
# Scores 0.9396122
# Bboxes [833 222 335 498]
# Class ids 39
# Scores 0.5156446
# Bboxes [852 106 300 614]
# Class ids 39
# Scores 0.9396122
# Bboxes [833 222 335 498]
# Class ids 39
# Scores 0.6418493
# Bboxes [841  93 288 627]
# Class ids 39
# Scores 0.8874976
# Bboxes [831 249 301 465]
# Class ids 39
# Scores 0.67124414
# Bboxes [833 111 293 609]
# Class ids 39
# Scores 0.75913334
# Bboxes [828 222 300 497]
# Class ids 39
# Scores 0.67124414
# Bboxes [833 111 293 609]
# Class ids 39
# Scores 0.75913334
# Bboxes [828 222 300 497]
# Class ids 39
# Scores 0.66767466
# Bboxes [823  79 301 641]
# Class ids 39
# Scores 0.702436
# Bboxes [807 225 320 495]
# Class ids 39
# Scores 0.75664234
# Bboxes [805 253 310 467]
# Class ids 39
# Scores 0.75664234
# Bboxes [805 253 310 467]
# Class ids 39
# Scores 0.53699726
# Bboxes [803 248 300 472]
# Class ids 39
# Scores 0.53699726
# Bboxes [803 248 300 472]
# Class ids 39
# Scores 0.5317688
# Bboxes [805 235 311 483]
# Class ids 39
# Scores 0.6565606
# Bboxes [807 213 330 507]
# Class ids 39
# Scores 0.7621883
# Bboxes [818 210 326 510]
# Class ids 39
# Scores 0.7621883
# Bboxes [818 210 326 510]
# Class ids 39
# Scores 0.674423
# Bboxes [846  65 285 655]
# Class ids 39
# Scores 0.8175309
# Bboxes [826 199 322 521]
# Class ids 39
# Scores 0.674423
# Bboxes [846  65 285 655]
# Class ids 39
# Scores 0.8175309
# Bboxes [826 199 322 521]
# Class ids 39
# Scores 0.6399665
# Bboxes [842  72 291 648]
# Class ids 39
# Scores 0.8167576
# Bboxes [819 186 330 534]
# Class ids 39
# Scores 0.6399665
# Bboxes [842  72 291 648]
# Class ids 39
# Scores 0.8167576
# Bboxes [819 186 330 534]
# Class ids 39
# Scores 0.51175165
# Bboxes [840  69 281 651]
# Class ids 39
# Scores 0.7081205
# Bboxes [823 206 308 514]
# Class ids 41
# Scores 0.69677204
# Bboxes [799 504 330 216]
# Class ids 39
# Scores 0.81316376
# Bboxes [816 211 317 509]
# Class ids 39
# Scores 0.66805816
# Bboxes [839  73 282 647]
# Class ids 39
# Scores 0.71413016
# Bboxes [821 239 312 481]
# Class ids 39
# Scores 0.66805816
# Bboxes [839  73 282 647]
# Class ids 39
# Scores 0.71413016
# Bboxes [821 239 312 481]
# Class ids 39
# Scores 0.8001127
# Bboxes [819 234 317 486]
# Class ids 39
# Scores 0.77280533
# Bboxes [821 250 301 470]
# Class ids 39
# Scores 0.77280533
# Bboxes [821 250 301 470]
# Class ids 39
# Scores 0.8483922
# Bboxes [813 250 284 466]
# Class ids 39
# Scores 0.79890746
# Bboxes [794 313 317 402]
# Class ids 39
# Scores 0.8483922
# Bboxes [813 250 284 466]
# Class ids 39
# Scores 0.79890746
# Bboxes [794 313 317 402]
# Class ids 39
# Scores 0.8757491
# Bboxes [799 235 303 485]
# Class ids 39
# Scores 0.69298697
# Bboxes [780 303 337 417]
# Class ids 39
# Scores 0.75523925
# Bboxes [796 241 313 476]
# Class ids 39
# Scores 0.78963035
# Bboxes [781 305 342 415]
# Class ids 39
# Scores 0.90981627
# Bboxes [814 245 278 472]
# Class ids 39
# Scores 0.584113
# Bboxes [796 306 313 414]
# Class ids 39
# Scores 0.90981627
# Bboxes [814 245 278 472]
# Class ids 39
# Scores 0.584113
# Bboxes [796 306 313 414]
# Class ids 39
# Scores 0.7802841
# Bboxes [816 252 292 460]
# Class ids 39
# Scores 0.7802841
# Bboxes [816 252 292 460]
# Class ids 39
# Scores 0.7276893
# Bboxes [811 224 300 496]
# Class ids 39
# Scores 0.7276893
# Bboxes [811 224 300 496]
# Class ids 39
# Scores 0.5550923
# Bboxes [814 269 296 433]
# Class ids 39
# Scores 0.5534151
# Bboxes [789 314 344 406]
# Class ids 39
# Scores 0.5550923
# Bboxes [814 269 296 433]
# Class ids 39
# Scores 0.5534151
# Bboxes [789 314 344 406]
# Class ids 39
# Scores 0.5217191
# Bboxes [785 316 339 404]
# Class ids 41
# Scores 0.5201767
# Bboxes [793 518 308 202]
# Class ids 39
# Scores 0.5217191
# Bboxes [785 316 339 404]
# Class ids 41
# Scores 0.5201767
# Bboxes [793 518 308 202]
# Class ids 39
# Scores 0.7757806
# Bboxes [809 258 306 445]
# Class ids 39
# Scores 0.8826817
# Bboxes [807 244 305 473]
# Class ids 39
# Scores 0.8874368
# Bboxes [787 315 336 403]
# Class ids 39
# Scores 0.83634096
# Bboxes [789 249 329 471]
# Class ids 39
# Scores 0.9019681
# Bboxes [775 336 354 383]
# Class ids 39
# Scores 0.83634096
# Bboxes [789 249 329 471]
# Class ids 39
# Scores 0.9019681
# Bboxes [775 336 354 383]
# Class ids 39
# Scores 0.9643905
# Bboxes [786 233 307 487]
# Class ids 39
# Scores 0.7566591
# Bboxes [769 310 344 410]
# Class ids 39
# Scores 0.9643905
# Bboxes [786 233 307 487]
# Class ids 39
# Scores 0.7566591
# Bboxes [769 310 344 410]
# Class ids 39
# Scores 0.91400343
# Bboxes [782 244 322 476]
# Class ids 39
# Scores 0.78292865
# Bboxes [774 306 349 414]
# Class ids 39
# Scores 0.91400343
# Bboxes [782 244 322 476]
# Class ids 39
# Scores 0.78292865
# Bboxes [774 306 349 414]
# Class ids 39
# Scores 0.88460433
# Bboxes [798 240 326 480]
# Class ids 39
# Scores 0.8662044
# Bboxes [786 315 347 400]
# Class ids 39
# Scores 0.70365834
# Bboxes [815 249 304 459]
# Class ids 39
# Scores 0.70365834
# Bboxes [815 249 304 459]
# Class ids 39
# Scores 0.6076292
# Bboxes [830 249 292 459]
# Class ids 39
# Scores 0.6076292
# Bboxes [830 249 292 459]
# Class ids 56
# Scores 0.5289937
# Bboxes [857 417 228  52]
# Class ids 56
# Scores 0.5289937
# Bboxes [857 417 228  52]
# Class ids 0
# Scores 0.57497436
# Bboxes [ 133   35 1130  685]
# Class ids 0
# Scores 0.593562
# Bboxes [211  35 972 685]
# Class ids 0
# Scores 0.593562
# Bboxes [211  35 972 685]
# Class ids 0
# Scores 0.56750566
# Bboxes [ 85  25 998 695]
# Class ids 0
# Scores 0.65292555
# Bboxes [212  33 971 687]
# Class ids 0
# Scores 0.56750566
# Bboxes [ 85  25 998 695]
# Class ids 0
# Scores 0.65292555
# Bboxes [212  33 971 687]
# Class ids 0
# Scores 0.5122332
# Bboxes [108  24 954 696]
# Class ids 0
# Scores 0.7191772
# Bboxes [197  28 997 692]
# Class ids 0
# Scores 0.5122332
# Bboxes [108  24 954 696]
# Class ids 0
# Scores 0.7191772
# Bboxes [197  28 997 692]
# Class ids 0
# Scores 0.526681
# Bboxes [104  37 966 683]
# Class ids 0
# Scores 0.75990754
# Bboxes [205  35 973 685]
# Class ids 0
# Scores 0.6050361
# Bboxes [  74   34 1013  686]
# Class ids 0
# Scores 0.7737888
# Bboxes [ 190   43 1005  677]
# Class ids 0
# Scores 0.62221664
# Bboxes [ 84  27 992 693]
# Class ids 0
# Scores 0.72616684
# Bboxes [ 172   31 1040  689]
# Class ids 0
# Scores 0.62221664
# Bboxes [ 84  27 992 693]
# Class ids 0
# Scores 0.72616684
# Bboxes [ 172   31 1040  689]
# Class ids 0
# Scores 0.73879063
# Bboxes [  76   34 1027  686]
# Class ids 0
# Scores 0.8115478
# Bboxes [ 174   36 1028  684]
# Class ids 0
# Scores 0.73879063
# Bboxes [  76   34 1027  686]
# Class ids 0
# Scores 0.8115478
# Bboxes [ 174   36 1028  684]
# Class ids 0
# Scores 0.595248
# Bboxes [100  42 948 678]
# Class ids 0
# Scores 0.57792383
# Bboxes [  0  33 950 687]
# Class ids 0
# Scores 0.5151476
# Bboxes [ 88  39 971 681]
# Class ids 0
# Scores 0.5396447
# Bboxes [ 152   27 1084  693]
# Class ids 0
# Scores 0.5396447
# Bboxes [ 152   27 1084  693]
# Class ids 0
# Scores 0.646673
# Bboxes [  26   23 1088  697]
# Class ids 0
# Scores 0.52153534
# Bboxes [ 197   28 1000  692]
# Class ids 0
# Scores 0.52153534
# Bboxes [ 197   28 1000  692]
# Class ids 0
# Scores 0.534801
# Bboxes [ 179   36 1036  684]
# Class ids 0
# Scores 0.534801
# Bboxes [ 179   36 1036  684]
# Class ids 56
# Scores 0.50069696
# Bboxes [  0 486 391 234]
# Class ids 0
# Scores 0.56660235
# Bboxes [  76   52 1015  668]
# Class ids 0
# Scores 0.56660235
# Bboxes [  76   52 1015  668]
# Class ids 15
# Scores 0.5360784
# Bboxes [429  62 352 265]
# Class ids 0
# Scores 0.5302732
# Bboxes [273 388 834 326]
# Class ids 0
# Scores 0.5302732
# Bboxes [273 388 834 326]
# Class ids 0
# Scores 0.56583995
# Bboxes [235 378 922 329]
# Class ids 0
# Scores 0.56583995
# Bboxes [235 378 922 329]
# Class ids 24
# Scores 0.60156447
# Bboxes [526 516 306 190]
# Class ids 24
# Scores 0.60156447
# Bboxes [526 516 306 190]
# Class ids 0
# Scores 0.6075188
# Bboxes [315 362 799 350]
# Class ids 0
# Scores 0.6075188
# Bboxes [315 362 799 350]
# Class ids 0
# Scores 0.685616
# Bboxes [339 343 753 373]
# Class ids 0
# Scores 0.5398502
# Bboxes [351 345 736 367]
# Class ids 0
# Scores 0.5398502
# Bboxes [351 345 736 367]
# Class ids 0
# Scores 0.56836665
# Bboxes [347 343 740 370]
# Class ids 0
# Scores 0.56836665
# Bboxes [347 343 740 370]
# Class ids 0
# Scores 0.6841413
# Bboxes [333 350 771 360]
# Class ids 0
# Scores 0.6122769
# Bboxes [293 364 828 350]
# Class ids 0
# Scores 0.6122769
# Bboxes [293 364 828 350]
# Class ids 0
# Scores 0.52548844
# Bboxes [302 378 802 341]
# Class ids 0
# Scores 0.52548844
# Bboxes [302 378 802 341]
# Class ids 0
# Scores 0.51489216
# Bboxes [308 383 794 337]
# Class ids 0
# Scores 0.50617963
# Bboxes [297 393 828 327]
# Class ids 0
# Scores 0.50617963
# Bboxes [297 393 828 327]
# Class ids 0
# Scores 0.7228761
# Bboxes [ 111   67 1169  637]
# Class ids 67
# Scores 0.59744036
# Bboxes [326 363 682 265]
# Class ids 67
# Scores 0.59744036
# Bboxes [326 363 682 265]
# Class ids 67
# Scores 0.593863
# Bboxes [335 356 674 268]
# Class ids 67
# Scores 0.593863
# Bboxes [335 356 674 268]
# Class ids 67
# Scores 0.60080856
# Bboxes [324 344 697 266]
# Class ids 67
# Scores 0.60080856
# Bboxes [324 344 697 266]
# Class ids 67
# Scores 0.50154614
# Bboxes [338 327 674 280]
# Class ids 67
# Scores 0.50154614
# Bboxes [338 327 674 280]
# Class ids 67
# Scores 0.5483637
# Bboxes [317 323 690 288]
# Class ids 67
# Scores 0.5483637
# Bboxes [317 323 690 288]
# Class ids 0
# Scores 0.573843
# Bboxes [379 459 559 261]
# Class ids 15
# Scores 0.5698631
# Bboxes [106  98 626 595]
# Class ids 15
# Scores 0.5698631
# Bboxes [106  98 626 595]
# Class ids 15
# Scores 0.5475467
# Bboxes [162  91 562 622]
# Class ids 15
# Scores 0.5475467
# Bboxes [162  91 562 622]
# Class ids 0
# Scores 0.772161
# Bboxes [352 126 439 562]
# Class ids 0
# Scores 0.772161
# Bboxes [352 126 439 562]
# Class ids 0
# Scores 0.5426579
# Bboxes [362 140 433 555]
# Class ids 0
# Scores 0.5426579
# Bboxes [362 140 433 555]
# Class ids 16
# Scores 0.664786
# Bboxes [377 156 441 528]
# Class ids 16
# Scores 0.664786
# Bboxes [377 156 441 528]
# Class ids 15
# Scores 0.58363783
# Bboxes [416 157 418 529]
# Class ids 15
# Scores 0.58363783
# Bboxes [416 157 418 529]
# Class ids 15
# Scores 0.6830924
# Bboxes [434 163 430 524]
# Class ids 15
# Scores 0.58582425
# Bboxes [436 176 429 535]
# Class ids 15
# Scores 0.6830924
# Bboxes [434 163 430 524]
# Class ids 15
# Scores 0.58582425
# Bboxes [436 176 429 535]
# Class ids 15
# Scores 0.5403834
# Bboxes [443 178 418 492]
# Class ids 15
# Scores 0.5119506
# Bboxes [444 181 424 523]
# Class ids 15
# Scores 0.5403834
# Bboxes [443 178 418 492]
# Class ids 15
# Scores 0.5119506
# Bboxes [444 181 424 523]
# Class ids 15
# Scores 0.5190701
# Bboxes [440 188 431 511]
# Class ids 15
# Scores 0.6015888
# Bboxes [444 195 419 499]
# Class ids 15
# Scores 0.6015888
# Bboxes [444 195 419 499]
# Class ids 16
# Scores 0.52595085
# Bboxes [447 205 415 492]
# Class ids 16
# Scores 0.52595085
# Bboxes [447 205 415 492]
# Class ids 15
# Scores 0.56185174
# Bboxes [443 203 413 490]
# Class ids 15
# Scores 0.54791486
# Bboxes [426 205 412 489]
# Class ids 15
# Scores 0.5057622
# Bboxes [450 203 397 493]
# Class ids 15
# Scores 0.64542925
# Bboxes [424 200 416 501]
# Class ids 15
# Scores 0.6551511
# Bboxes [453 202 391 496]
# Class ids 15
# Scores 0.64542925
# Bboxes [424 200 416 501]
# Class ids 15
# Scores 0.6551511
# Bboxes [453 202 391 496]
# Class ids 15
# Scores 0.58441645
# Bboxes [421 190 421 508]
# Class ids 15
# Scores 0.58441645
# Bboxes [421 190 421 508]
# Class ids 15
# Scores 0.69711775
# Bboxes [418 194 425 504]
# Class ids 15
# Scores 0.5176989
# Bboxes [441 195 412 501]
# Class ids 15
# Scores 0.67168164
# Bboxes [417 202 428 491]
# Class ids 15
# Scores 0.64579785
# Bboxes [441 198 416 495]
# Class ids 15
# Scores 0.67168164
# Bboxes [417 202 428 491]
# Class ids 15
# Scores 0.64579785
# Bboxes [441 198 416 495]
# Class ids 15
# Scores 0.51433295
# Bboxes [414 197 436 497]
# Class ids 15
# Scores 0.6679518
# Bboxes [443 196 417 499]
# Class ids 15
# Scores 0.51433295
# Bboxes [414 197 436 497]
# Class ids 15
# Scores 0.6679518
# Bboxes [443 196 417 499]
# Class ids 15
# Scores 0.6721217
# Bboxes [415 200 433 493]
# Class ids 15
# Scores 0.6634983
# Bboxes [438 196 425 499]
# Class ids 15
# Scores 0.5726267
# Bboxes [436 195 430 508]
# Class ids 15
# Scores 0.5726267
# Bboxes [436 195 430 508]
# Class ids 15
# Scores 0.5689156
# Bboxes [439 195 428 499]
# Class ids 15
# Scores 0.5689156
# Bboxes [439 195 428 499]
# Class ids 0
# Scores 0.7665912
# Bboxes [435 203 433 487]
# Class ids 15
# Scores 0.7251319
# Bboxes [443 208 414 480]
# Class ids 15
# Scores 0.68451
# Bboxes [436 205 431 490]
# Class ids 15
# Scores 0.68451
# Bboxes [436 205 431 490]
# Class ids 15
# Scores 0.5733726
# Bboxes [435 206 436 488]
# Class ids 15
# Scores 0.5733726
# Bboxes [435 206 436 488]
# Class ids 15
# Scores 0.7162273
# Bboxes [440 200 422 501]
# Class ids 0
# Scores 0.7157192
# Bboxes [437 202 439 494]
# Class ids 0
# Scores 0.7157192
# Bboxes [437 202 439 494]
# Class ids 0
# Scores 0.7544642
# Bboxes [433 200 444 500]
# Class ids 0
# Scores 0.7544642
# Bboxes [433 200 444 500]
# Class ids 0
# Scores 0.8090586
# Bboxes [437 202 435 496]
# Class ids 0
# Scores 0.8090586
# Bboxes [437 202 435 496]
# Class ids 15
# Scores 0.70599586
# Bboxes [435 203 434 499]
# Class ids 15
# Scores 0.7104687
# Bboxes [430 208 444 496]
# Class ids 15
# Scores 0.7909847
# Bboxes [430 202 447 506]
# Class ids 57
# Scores 0.51204425
# Bboxes [823 644 448  74]
# Class ids 15
# Scores 0.7909847
# Bboxes [430 202 447 506]
# Class ids 57
# Scores 0.51204425
# Bboxes [823 644 448  74]
# Class ids 15
# Scores 0.70877093
# Bboxes [433 204 446 504]
# Class ids 15
# Scores 0.70877093
# Bboxes [433 204 446 504]
# Class ids 15
# Scores 0.58398354
# Bboxes [433 204 443 501]
# Class ids 15
# Scores 0.5294492
# Bboxes [436 207 432 490]
# Class ids 15
# Scores 0.5294492
# Bboxes [436 207 432 490]
# Class ids 15
# Scores 0.686767
# Bboxes [433 207 436 492]
# Class ids 15
# Scores 0.67058015
# Bboxes [429 201 449 501]
# Class ids 15
# Scores 0.67058015
# Bboxes [429 201 449 501]
# Class ids 15
# Scores 0.6148293
# Bboxes [432 203 445 496]
# Class ids 15
# Scores 0.537129
# Bboxes [428 206 444 488]
# Class ids 15
# Scores 0.537129
# Bboxes [428 206 444 488]
# Class ids 0
# Scores 0.6568101
# Bboxes [430 206 449 494]
# Class ids 0
# Scores 0.6568101
# Bboxes [430 206 449 494]
# Class ids 15
# Scores 0.7102159
# Bboxes [426 205 455 495]
# Class ids 15
# Scores 0.7102159
# Bboxes [426 205 455 495]
# Class ids 15
# Scores 0.64837605
# Bboxes [433 201 440 508]
# Class ids 15
# Scores 0.64837605
# Bboxes [433 201 440 508]
# Class ids 0
# Scores 0.6556993
# Bboxes [441 205 423 497]
# Class ids 0
# Scores 0.6556993
# Bboxes [441 205 423 497]
# Class ids 15
# Scores 0.6628456
# Bboxes [428 204 448 497]
# Class ids 15
# Scores 0.70768154
# Bboxes [410 199 441 494]
# Class ids 15
# Scores 0.64089775
# Bboxes [429 202 442 492]
# Class ids 15
# Scores 0.6340583
# Bboxes [408 207 443 492]
# Class ids 15
# Scores 0.65499413
# Bboxes [430 203 442 498]
# Class ids 15
# Scores 0.59319705
# Bboxes [468 207 423 506]
# Class ids 0
# Scores 0.50157493
# Bboxes [543 200 495 508]
# Class ids 15
# Scores 0.7830449
# Bboxes [547 199 488 506]
# Class ids 15
# Scores 0.7830449
# Bboxes [547 199 488 506]
# Class ids 15
# Scores 0.7470251
# Bboxes [518 209 487 501]
# Class ids 15
# Scores 0.83526105
# Bboxes [548 212 471 488]
# Class ids 0
# Scores 0.6542391
# Bboxes [521 204 479 504]
# Class ids 0
# Scores 0.71152043
# Bboxes [556 211 452 493]
# Class ids 0
# Scores 0.6542391
# Bboxes [521 204 479 504]
# Class ids 0
# Scores 0.71152043
# Bboxes [556 211 452 493]
# Class ids 0
# Scores 0.6025902
# Bboxes [523 205 464 515]
# Class ids 0
# Scores 0.6025902
# Bboxes [523 205 464 515]
# Class ids 0
# Scores 0.6596718
# Bboxes [538 217 422 503]
# Class ids 0
# Scores 0.5872647
# Bboxes [530 198 427 500]
# Class ids 0
# Scores 0.50962603
# Bboxes [524 202 446 495]
# Class ids 0
# Scores 0.50962603
# Bboxes [524 202 446 495]
# Class ids 16
# Scores 0.5684563
# Bboxes [531 198 430 502]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 69
#      66 # Display buttons
#      68 cv2.imshow("Frame", frame)
# ---> 69 key = cv2.waitKey(1)
#      70 if key == 27:
#      71     break
#
# KeyboardInterrupt:
